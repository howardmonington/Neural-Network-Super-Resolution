# %% [markdown]
# https://medium.com/beyondminds/an-introduction-to-super-resolution-using-deep-learning-f60aff9a499d
# dataset can be found here: https://www.kaggle.com/olgabelitskaya/flower-color-images
# tensorflow code can be found here: https://www.tensorflow.org/hub/tutorials/image_enhancing

# %%
import tensorflow as tf
import numpy as np
import os
import time
from PIL import Image
import tensorflow_hub as hub

# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import itertools
from tensorflow import keras
os.environ["TFHUB_DOWNLOAD_PROGRESS"] = "True"
from PIL import Image

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.version.VERSION
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Importing the data

# %%
base_dir = os.path.join(os.getcwd(), os.pardir, "flowers","flowers")

# %%
flower_pictures = os.listdir(base_dir)
print(flower_pictures[:10])
# Out:
# ['00_001.png', '00_002.png', '00_003.png', '00_004.png', '00_005.png', '00_006.png', '00_007.png', '00_008.png', '00_009.png', '00_010.png']

# %%
print("Dataset contains " + str(len(flower_pictures)) + " pictures")
# Out:
# Dataset contains 603 pictures

# %%
# Loads image from path and preprocesses to make it model ready
def preprocess_image(image_path):
    # reads file from image path and decodes image as a tf EagerTensor
    hr_image = tf.image.decode_image(tf.io.read_file(image_path))
    # the model I'm using only supports images with 3 color channels
    # my dataset is composed of png files which have 4 color chanels, so I'm going to remove the alpha channel to have 3 channels
    hr_image = hr_image[...,:-1]
    # cast to float32 instead of int
    hr_image = tf.cast(hr_image, tf.float32)
    # add a dimension to the beginning
    hr_image = tf.expand_dims(hr_image, 0)
    return hr_image

# %%
# ensures the image is in the correct Image.Image format, then saves the image as a jpg
def save_image(image, filename):
    # checking if image is type Image.Image (values between 0-255 and of type uint8)
    if not isinstance(image, Image.Image):
    # modifying the image to have values between 0-255 and to be of type unint8
        image = tf.clip_by_value(image, 0, 255)
        image = Image.fromarray(tf.cast(image, tf.uint8).numpy())
    # save the image as a jpg using the name specified
    image.save("%s.jpg" % filename)
    print("Saved as %s.jpg" % filename)

# %%
# plots the image
def plot_image(image, title=""):
    # converting to int32 since images with type int can have values between 0-255
    # whereas images with type float can have values between 0-1
    image = tf.cast(image, tf.int32).numpy()
    # clipping the image to ensure it is within the range of 0-255
    image = tf.clip_by_value(image, 0, 255)
    # altering the figure size to be slightly larger, in order to better see the blurriness/sharpness of the image
    plt.figure(figsize=(5, 5))
    # showing the image
    plt.imshow(tf.squeeze(image))
    # removing the axes from view
    plt.axis("off")
    # titling the plot
    plt.title(title)

# %%
image_1 = os.path.join(base_dir, flower_pictures[100])

# %%
hr_image = preprocess_image(image_1)

# %%
plot_image(hr_image)

# %%
SAVED_MODEL_PATH = "https://tfhub.dev/captain-pool/esrgan-tf2/1"

# %%
model = hub.load(SAVED_MODEL_PATH)
# Out:
# Downloaded https://tfhub.dev/captain-pool/esrgan-tf2/1, Total size: 20.60MB

# %%
start = time.time()
fake_image = model(hr_image)
fake_image = tf.squeeze(fake_image)
print("Time Taken: %f" % (time.time() - start))
# Out:
# Time Taken: 2.777114

# %%
plot_image(tf.squeeze(fake_image), title= "Super Resolution")

# %%
hr_image = preprocess_image(image_1)

# %%
hr_image = tf.squeeze(hr_image).shape

# %%
arr = np.asarray(hr_image)

# %%
arr
# Out:
# array([[[[ 13.,  22.,  10.],
#          [ 14.,  23.,   9.],
#          [ 16.,  24.,  10.],
#          ...,
#          [128., 143.,  78.],
#          [134., 148.,  85.],
#          [125., 140.,  78.]],
#
#         [[ 15.,  21.,  10.],
#          [ 14.,  23.,   9.],
#          [ 17.,  25.,  11.],
#          ...,
#          [126., 152.,  81.],
#          [146., 170.,  96.],
#          [139., 158.,  94.]],
#
#         [[ 16.,  24.,  10.],
#          [ 17.,  25.,  11.],
#          [ 17.,  25.,  12.],
#          ...,
#          [ 48.,  72.,  32.],
#          [112., 139.,  67.],
#          [135., 157.,  88.]],
#
#         ...,
#
#         [[ 92.,  75.,  56.],
#          [ 97.,  78.,  58.],
#          [ 98.,  79.,  58.],
#          ...,
#          [ 76.,  61.,  44.],
#          [ 69.,  52.,  40.],
#          [ 54.,  44.,  37.]],
#
#         [[ 90.,  75.,  56.],
#          [ 94.,  77.,  57.],
#          [ 97.,  79.,  59.],
#          ...,
#          [ 63.,  46.,  38.],
#          [ 38.,  30.,  22.],
#          [ 87.,  61.,  57.]],
#
#         [[ 89.,  73.,  55.],
#          [ 96.,  77.,  58.],
#          [ 99.,  80.,  61.],
#          ...,
#          [ 59.,  38.,  38.],
#          [ 26.,  25.,  16.],
#          [117.,  74.,  78.]]]], dtype=float32)

# %%
save_image(tf.squeeze(hr_image), "test")
# Out:
# Saved as test.jpg

# %%
hr_image2 = tf.squeeze(hr_image)

# %%
isinstance(hr_image2, Image.Image)
# Out:
# False

# %%
hr_image2 = tf.clip_by_value(hr_image2, 0, 255)
hr_image2 = Image.fromarray(tf.cast(hr_image2, tf.uint8).numpy())

# %%
isinstance(hr_image2, Image.Image)
# Out:
# True

# %%
hr_image
# Out:
# <tf.Tensor: shape=(1, 128, 128, 3), dtype=float32, numpy=
# array([[[[ 13.,  22.,  10.],
#          [ 14.,  23.,   9.],
#          [ 16.,  24.,  10.],
#          ...,
#          [128., 143.,  78.],
#          [134., 148.,  85.],
#          [125., 140.,  78.]],
#
#         [[ 15.,  21.,  10.],
#          [ 14.,  23.,   9.],
#          [ 17.,  25.,  11.],
#          ...,
#          [126., 152.,  81.],
#          [146., 170.,  96.],
#          [139., 158.,  94.]],
#
#         [[ 16.,  24.,  10.],
#          [ 17.,  25.,  11.],
#          [ 17.,  25.,  12.],
#          ...,
#          [ 48.,  72.,  32.],
#          [112., 139.,  67.],
#          [135., 157.,  88.]],
#
#         ...,
#
#         [[ 92.,  75.,  56.],
#          [ 97.,  78.,  58.],
#          [ 98.,  79.,  58.],
#          ...,
#          [ 76.,  61.,  44.],
#          [ 69.,  52.,  40.],
#          [ 54.,  44.,  37.]],
#
#         [[ 90.,  75.,  56.],
#          [ 94.,  77.,  57.],
#          [ 97.,  79.,  59.],
#          ...,
#          [ 63.,  46.,  38.],
#          [ 38.,  30.,  22.],
#          [ 87.,  61.,  57.]],
#
#         [[ 89.,  73.,  55.],
#          [ 96.,  77.,  58.],
#          [ 99.,  80.,  61.],
#          ...,
#          [ 59.,  38.,  38.],
#          [ 26.,  25.,  16.],
#          [117.,  74.,  78.]]]], dtype=float32)>

# %%
hr_image = Image.fromarray(tf.cast(hr_image, tf.uint8).numpy())
#hr_image.save("test.jpg)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2748         try:
# -> 2749             mode, rawmode = _fromarray_typemap[typekey]
#    2750         except KeyError as e:
#
# KeyError: ((1, 1, 128, 3), '|u1')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-e55a5f82a7ee> in <module>
# ----> 1 hr_image = Image.fromarray(tf.cast(hr_image, tf.uint8).numpy())
#       2 #hr_image.save("test.jpg)")
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\PIL\Image.py in fromarray(obj, mode)
#    2749             mode, rawmode = _fromarray_typemap[typekey]
#    2750         except KeyError as e:
# -> 2751             raise TypeError("Cannot handle this data type: %s, %s" % typekey) from e
#    2752     else:
#    2753         rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 128, 3), |u1

# %%
tf.clip_by_value(hr_image, 0, 100)
# Out:
# <tf.Tensor: shape=(1, 128, 128, 3), dtype=float32, numpy=
# array([[[[ 13.,  22.,  10.],
#          [ 14.,  23.,   9.],
#          [ 16.,  24.,  10.],
#          ...,
#          [100., 100.,  78.],
#          [100., 100.,  85.],
#          [100., 100.,  78.]],
#
#         [[ 15.,  21.,  10.],
#          [ 14.,  23.,   9.],
#          [ 17.,  25.,  11.],
#          ...,
#          [100., 100.,  81.],
#          [100., 100.,  96.],
#          [100., 100.,  94.]],
#
#         [[ 16.,  24.,  10.],
#          [ 17.,  25.,  11.],
#          [ 17.,  25.,  12.],
#          ...,
#          [ 48.,  72.,  32.],
#          [100., 100.,  67.],
#          [100., 100.,  88.]],
#
#         ...,
#
#         [[ 92.,  75.,  56.],
#          [ 97.,  78.,  58.],
#          [ 98.,  79.,  58.],
#          ...,
#          [ 76.,  61.,  44.],
#          [ 69.,  52.,  40.],
#          [ 54.,  44.,  37.]],
#
#         [[ 90.,  75.,  56.],
#          [ 94.,  77.,  57.],
#          [ 97.,  79.,  59.],
#          ...,
#          [ 63.,  46.,  38.],
#          [ 38.,  30.,  22.],
#          [ 87.,  61.,  57.]],
#
#         [[ 89.,  73.,  55.],
#          [ 96.,  77.,  58.],
#          [ 99.,  80.,  61.],
#          ...,
#          [ 59.,  38.,  38.],
#          [ 26.,  25.,  16.],
#          [100.,  74.,  78.]]]], dtype=float32)>

# %%
hr_image
# Out:
# <tf.Tensor: shape=(1, 128, 128, 3), dtype=float32, numpy=
# array([[[[ 13.,  22.,  10.],
#          [ 14.,  23.,   9.],
#          [ 16.,  24.,  10.],
#          ...,
#          [128., 143.,  78.],
#          [134., 148.,  85.],
#          [125., 140.,  78.]],
#
#         [[ 15.,  21.,  10.],
#          [ 14.,  23.,   9.],
#          [ 17.,  25.,  11.],
#          ...,
#          [126., 152.,  81.],
#          [146., 170.,  96.],
#          [139., 158.,  94.]],
#
#         [[ 16.,  24.,  10.],
#          [ 17.,  25.,  11.],
#          [ 17.,  25.,  12.],
#          ...,
#          [ 48.,  72.,  32.],
#          [112., 139.,  67.],
#          [135., 157.,  88.]],
#
#         ...,
#
#         [[ 92.,  75.,  56.],
#          [ 97.,  78.,  58.],
#          [ 98.,  79.,  58.],
#          ...,
#          [ 76.,  61.,  44.],
#          [ 69.,  52.,  40.],
#          [ 54.,  44.,  37.]],
#
#         [[ 90.,  75.,  56.],
#          [ 94.,  77.,  57.],
#          [ 97.,  79.,  59.],
#          ...,
#          [ 63.,  46.,  38.],
#          [ 38.,  30.,  22.],
#          [ 87.,  61.,  57.]],
#
#         [[ 89.,  73.,  55.],
#          [ 96.,  77.,  58.],
#          [ 99.,  80.,  61.],
#          ...,
#          [ 59.,  38.,  38.],
#          [ 26.,  25.,  16.],
#          [117.,  74.,  78.]]]], dtype=float32)>

# %%
tf.expand_dims(hr_image, 0)
# Out:
# <tf.Tensor: shape=(1, 128, 128, 4), dtype=uint8, numpy=
# array([[[[ 13,  22,  10, 255],
#          [ 14,  23,   9, 255],
#          [ 16,  24,  10, 255],
#          ...,
#          [128, 143,  78, 255],
#          [134, 148,  85, 255],
#          [125, 140,  78, 255]],
#
#         [[ 15,  21,  10, 255],
#          [ 14,  23,   9, 255],
#          [ 17,  25,  11, 255],
#          ...,
#          [126, 152,  81, 255],
#          [146, 170,  96, 255],
#          [139, 158,  94, 255]],
#
#         [[ 16,  24,  10, 255],
#          [ 17,  25,  11, 255],
#          [ 17,  25,  12, 255],
#          ...,
#          [ 48,  72,  32, 255],
#          [112, 139,  67, 255],
#          [135, 157,  88, 255]],
#
#         ...,
#
#         [[ 92,  75,  56, 255],
#          [ 97,  78,  58, 255],
#          [ 98,  79,  58, 255],
#          ...,
#          [ 76,  61,  44, 255],
#          [ 69,  52,  40, 255],
#          [ 54,  44,  37, 255]],
#
#         [[ 90,  75,  56, 255],
#          [ 94,  77,  57, 255],
#          [ 97,  79,  59, 255],
#          ...,
#          [ 63,  46,  38, 255],
#          [ 38,  30,  22, 255],
#          [ 87,  61,  57, 255]],
#
#         [[ 89,  73,  55, 255],
#          [ 96,  77,  58, 255],
#          [ 99,  80,  61, 255],
#          ...,
#          [ 59,  38,  38, 255],
#          [ 26,  25,  16, 255],
#          [117,  74,  78, 255]]]], dtype=uint8)>

# %%
hr_image3 = hr_image[...:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-4081fb921aa1> in <module>
# ----> 1 hr_image3 = hr_image[...:20,:-1]
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py in _slice_helper(tensor, slice_spec, var)
#     980     if isinstance(s, _BaseSlice):
#     981       if s.start is not None and not _is_undefined_dimension(s.start):
# --> 982         _check_index(s.start)
#     983         begin.append(s.start)
#     984       else:
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\array_ops.py in _check_index(idx)
#     884     # TODO(slebedev): IndexError seems more appropriate here, but it
#     885     # will break `_slice_helper` contract.
# --> 886     raise TypeError(_SLICE_TYPE_ERROR + ", got {!r}".format(idx))
#     887
#     888
#
# TypeError: Only integers, slices (`:`), ellipsis (`...`), tf.newaxis (`None`) and scalar tf.int32/tf.int64 tensors are valid indices, got Ellipsis

# %%
hr_image3.shape
# Out:
# TensorShape([128, 128, 4])

# %%
hr_image.shape
# Out:
# TensorShape([128, 128, 4])

# %%
hr_size = tf.convert_to_tensor(hr_image.shape[:-1])

# %%
hr_size = (tf.convert_to_tensor(hr_image.shape[:-1]) // 4) * 4

# %%
hr_size
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([128, 128])>

# %%
print(tf.convert_to_tensor(hr_image.shape[:-1]))
# Out:
# tf.Tensor([128 128], shape=(2,), dtype=int32)

# %%
test2 = (tf.convert_to_tensor(hr_image.shape[:-1]) // 4) * 4

# %%
test2
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([128, 128])>

# %%
test = tf.convert_to_tensor(hr_image.shape[:-1]) // 4

# %%
test
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([32, 32])>

# %%
hr_image2 = hr_image[...,:-1]

# %%
hr_image2
# Out:
# <tf.Tensor: shape=(128, 128, 3), dtype=uint8, numpy=
# array([[[ 13,  22,  10],
#         [ 14,  23,   9],
#         [ 16,  24,  10],
#         ...,
#         [128, 143,  78],
#         [134, 148,  85],
#         [125, 140,  78]],
#
#        [[ 15,  21,  10],
#         [ 14,  23,   9],
#         [ 17,  25,  11],
#         ...,
#         [126, 152,  81],
#         [146, 170,  96],
#         [139, 158,  94]],
#
#        [[ 16,  24,  10],
#         [ 17,  25,  11],
#         [ 17,  25,  12],
#         ...,
#         [ 48,  72,  32],
#         [112, 139,  67],
#         [135, 157,  88]],
#
#        ...,
#
#        [[ 92,  75,  56],
#         [ 97,  78,  58],
#         [ 98,  79,  58],
#         ...,
#         [ 76,  61,  44],
#         [ 69,  52,  40],
#         [ 54,  44,  37]],
#
#        [[ 90,  75,  56],
#         [ 94,  77,  57],
#         [ 97,  79,  59],
#         ...,
#         [ 63,  46,  38],
#         [ 38,  30,  22],
#         [ 87,  61,  57]],
#
#        [[ 89,  73,  55],
#         [ 96,  77,  58],
#         [ 99,  80,  61],
#         ...,
#         [ 59,  38,  38],
#         [ 26,  25,  16],
#         [117,  74,  78]]], dtype=uint8)>

# %%
hr_image2.shape
# Out:
# TensorShape([128, 128, 3])

# %%
type(hr_image)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
plt.imshow(test2)
plt.axis('Off')
plt.rcParams["figure.figsize"] = (10,7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-7a5a8e392650> in <module>
# ----> 1 plt.imshow(test2)
#       2 plt.axis('Off')
#       3 plt.rcParams["figure.figsize"] = (10,7)
#       4 plt.show()
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~\Anaconda3\envs\tensorflow-gpu\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     709         if not (self._A.ndim == 2
#     710                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 711             raise TypeError("Invalid shape {} for image data"
#     712                             .format(self._A.shape))
#     713
#
# TypeError: Invalid shape (2,) for image data
